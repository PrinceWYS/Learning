# %%
import torch
import torch.nn as nn
from torch.nn import init
import numpy as np

import sys
sys.path.append('..')
import d2dl

# %% [markdown]
# Define model

# %%
num_inputs, num_outputs, num_hiddens = 784, 10, 256

net = nn.Sequential(
    d2dl.FlattenLayer(),
    nn.Linear(num_inputs, num_hiddens),
    nn.ReLU(),
    nn.Linear(num_hiddens, num_outputs),
)

for params in net.parameters():
    init.normal_(params, mean=0, std=0.01)

# %% [markdown]
# Load data and train

# %%
batch_size = 256
train_iter, test_iter = d2dl.load_data_fashion_mnist(batch_size)

loss = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(net.parameters(), lr=0.5)

num_epochs = 5
d2dl.train_ch3(net, train_iter, test_iter, loss, num_epochs, batch_size, None, None, optimizer)
# Out:
# epoch 1, loss 0.0032, train acc 0.693, test acc 0.768
# epoch 2, loss 0.0019, train acc 0.817, test acc 0.819
# epoch 3, loss 0.0017, train acc 0.844, test acc 0.794
# epoch 4, loss 0.0015, train acc 0.855, test acc 0.851
# epoch 5, loss 0.0015, train acc 0.863, test acc 0.840
